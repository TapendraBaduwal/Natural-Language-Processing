# %% [markdown]
# https://www.dataquest.io/blog/web-scraping-python-using-beautiful-soup/

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
import requests
from bs4 import BeautifulSoup

page = requests.get("https://forecast.weather.gov/MapClick.php?lat=37.7772&lon=-122.4168")
soup = BeautifulSoup(page.content, 'html.parser')
seven_day = soup.find(id="seven-day-forecast-list")
forecast_items = seven_day.find_all(class_="tombstone-container")
tonight = forecast_items[0]
print(tonight.prettify())
# Out:
# <div class="tombstone-container">
#  <p class="period-name">
#   Overnight
#   <br/>
#   <br/>
#  </p>
#  <p>
#   <img alt="Overnight: Mostly cloudy, with a low around 53. West southwest wind 14 to 17 mph, with gusts as high as 22 mph. " class="forecast-icon" src="newimages/medium/nbkn.png" title="Overnight: Mostly cloudy, with a low around 53. West southwest wind 14 to 17 mph, with gusts as high as 22 mph. "/>
#  </p>
#  <p class="short-desc">
#   Mostly Cloudy
#  </p>
#  <p class="temp temp-low">
#   Low: 53 °F
#  </p>
# </div>

# %%
period = tonight.find(class_="period-name").get_text()
short_desc = tonight.find(class_="short-desc").get_text()
temp = tonight.find(class_="temp").get_text()
print(period)
print(short_desc)
print(temp)
# Out:
# Overnight
# Mostly Cloudy
# Low: 53 °F

# %%
img = tonight.find("img")
desc = img['title']
print(desc)
# Out:
# Overnight: Mostly cloudy, with a low around 53. West southwest wind 15 to 18 mph, with gusts as high as 23 mph.

# %%
period_tags = seven_day.select(".tombstone-container .period-name")
periods = [pt.get_text() for pt in period_tags]
periods
# Out:
# ['Overnight',
#  'Friday',
#  'FridayNight',
#  'Saturday',
#  'SaturdayNight',
#  'Sunday',
#  'SundayNight',
#  'MemorialDay',
#  'MondayNight']

# %%
short_descs = [sd.get_text() for sd in seven_day.select(".tombstone-container .short-desc")]
temps = [t.get_text() for t in seven_day.select(".tombstone-container .temp")]
descs = [d["title"] for d in seven_day.select(".tombstone-container img")]
print(short_descs)
print(temps)
print(descs)
# Out:
# ['Mostly Cloudy', 'Mostly Cloudythen MostlySunny andBreezy', 'Mostly Cloudyand Breezythen MostlyCloudy', 'Partly Sunny', 'Partly Cloudy', 'Sunny', 'Clear andBreezy thenClear', 'Sunny', 'Clear']
# ['Low: 53 °F', 'High: 65 °F', 'Low: 52 °F', 'High: 65 °F', 'Low: 51 °F', 'High: 65 °F', 'Low: 50 °F', 'High: 67 °F', 'Low: 51 °F']
# ['Overnight: Mostly cloudy, with a low around 53. West southwest wind 15 to 18 mph, with gusts as high as 23 mph. ', 'Friday: Cloudy, then gradually becoming mostly sunny, with a high near 65. Breezy, with a west southwest wind 14 to 23 mph, with gusts as high as 31 mph. ', 'Friday Night: Mostly cloudy, with a low around 52. Breezy, with a west wind 16 to 24 mph, with gusts as high as 32 mph. ', 'Saturday: Partly sunny, with a high near 65. Southwest wind 8 to 15 mph, with gusts as high as 20 mph. ', 'Saturday Night: Partly cloudy, with a low around 51. West wind 9 to 13 mph. ', 'Sunday: Sunny, with a high near 65.', 'Sunday Night: Clear, with a low around 50. Breezy. ', 'Memorial Day: Sunny, with a high near 67.', 'Monday Night: Clear, with a low around 51.']

# %%
import pandas as pd

weather = pd.DataFrame({
    "period": periods,
    "short_desc": short_descs,
    "temp": temps,
    "desc":descs
})
weather
# Out:
#           period                                short_desc         temp  \
# 0      Overnight                             Mostly Cloudy   Low: 53 °F
# 1         Friday   Mostly Cloudythen MostlySunny andBreezy  High: 65 °F
# 2    FridayNight  Mostly Cloudyand Breezythen MostlyCloudy   Low: 52 °F
# 3       Saturday                              Partly Sunny  High: 65 °F
# 4  SaturdayNight                             Partly Cloudy   Low: 51 °F
# 5         Sunday                                     Sunny  High: 65 °F
# 6    SundayNight                 Clear andBreezy thenClear   Low: 50 °F
# 7    MemorialDay                                     Sunny  High: 67 °F
# 8    MondayNight                                     Clear   Low: 51 °F
#
#                                                 desc
# 0  Overnight: Mostly cloudy, with a low around 53...
# 1  Friday: Cloudy, then gradually becoming mostly...
# 2  Friday Night: Mostly cloudy, with a low around...
# 3  Saturday: Partly sunny, with a high near 65. S...
# 4  Saturday Night: Partly cloudy, with a low arou...
# 5                Sunday: Sunny, with a high near 65.
# 6  Sunday Night: Clear, with a low around 50. Bre...
# 7          Memorial Day: Sunny, with a high near 67.
# 8         Monday Night: Clear, with a low around 51.
